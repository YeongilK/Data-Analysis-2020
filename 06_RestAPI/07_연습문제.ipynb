# %% [markdown]
# # Exercise - 강서구 커피 매장 정보

# %%
import pandas as pd 
import numpy as np
import folium

# %%
df = pd.read_csv('../input/coffee.csv', encoding='euc-kr')
df.head()
# Out:
#      상가업소번호            상호명         지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  19911397  커피빈코리아선릉로93길점  코리아선릉로93길점         Q       음식       Q12   커피점/카페
# 1  20020124          스완카페트         NaN         Q       음식       Q12   커피점/카페
# 2  19973708             왕실         NaN         Q       음식       Q12   커피점/카페
# 3  20004707            커피빈      코리아교대점         Q       음식       Q12   커피점/카페
# 4  19993199   고려대학교교육관쎄리오점         NaN         Q       음식       Q12   커피점/카페
#
#   상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0    Q12A01  커피전문점/카페/다방   I56220  ...  1168010100106960042022041
# 1    Q12A01  커피전문점/카페/다방   I56220  ...  1156013300106040056037792
# 2    Q12A01  커피전문점/카페/다방   I56220  ...  1114012700101050000019781
# 3    Q12A01  커피전문점/카페/다방   I56220  ...  1165010800116570005024412
# 4    Q12A01  커피전문점/카페/다방   I56220  ...  1129012500100010002039525
#
#                  건물명                    도로명주소     구우편번호   신우편번호  동정보 층정보  호정보  \
# ...

# %%
len(df.index)
# Out:
# 93253

# %%
# 도로명주소에 '서울특별시 강서구' 를 포함한 행만 추출
keyword = '서울특별시 강서구'
df2 = df.loc[df['도로명주소'].str.contains(keyword, na=False)]
len(df2)
# Out:
# 742

# %%
a = df2.loc[df2['상호명'].str.contains('이디야', na=False)]
len(a)
# Out:
# 39

# %%
b = df2.loc[df2['상호명'].str.lower().str.contains('ediya', na=False)]
b
# Out:
#          상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 6809   25475719  EDIYACOFFEE  NaN         Q       음식       Q12   커피점/카페
# 12522  11761351      EDIYA카페  NaN         Q       음식       Q12   커피점/카페
#
#       상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 6809     Q12A01  커피전문점/카페/다방   I56220  ...  1150010100102400021028397  우림블루나인
# 12522    Q12A01  커피전문점/카페/다방   I56220  ...  1150010800100530015007568     NaN
#
#                    도로명주소     구우편번호   신우편번호  동정보 층정보  호정보          경도  \
# 6809   서울특별시 강서구 양천로 583  157779.0  7547.0  NaN   1  NaN  126.864328
# 12522   서울특별시 강서구 송정로 70  157812.0  7623.0  NaN   2  NaN  126.809952
#
#               위도
# 6809   37.557106
# 12522  37.560949
#
# [2 rows x 39 columns]

# %%
condition = df2['상호명'].str.contains('투썸', na=False) | df2['상호명'].str.lower().str.contains('two', na=False)
df2.loc[condition]
# Out:
#          상가업소번호            상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 672    23749411     투썸플레이스등촌로점     등촌로점         Q       음식       Q12   커피점/카페
# 5763   19987539         투썸플레이스     가양역점         Q       음식       Q12   커피점/카페
# 8308   20783999         투썸플레이스   양천향교역점         Q       음식       Q12   커피점/카페
# 8343   23462941         투썸플레이스    까치산역점         Q       음식       Q12   커피점/카페
# 8526   23674620    투썸플레이스개화산역점    개화산역점         Q       음식       Q12   커피점/카페
# 11030  25797498    투썸플레이스우장산역점    우장산역점         Q       음식       Q12   커피점/카페
# 13051  12122351     투썸플레이스발산역점     발산역점         Q       음식       Q12   커피점/카페
# 13192  11932392  투썸플레이스골든서울호텔점  골든서울호텔점         Q       음식       Q12   커피점/카페
# 14490  12476713         투썸플레이스    신방화역점         Q       음식       Q12   커피점/카페
# 15561  12110411           투썸강서     송정역점         Q       음식       Q12   커피점/카페
# 18569  15891274         투썸플레이스      등촌점         Q       음식       Q12   커피점/카페
# ...

# %% [markdown]
# #### 서울특별시 강서구에 있는 스타벅스, 이디야, 빽다방, 투썸플레이스 매장만 추출하여 데이터프레임에 저장

# %%
# 상호명이 영어로 되어있는 지점들까지 포함시켜주는 조건들
condition_s = df2['상호명'].str.contains('스타벅스', na=False) | df2['상호명'].str.lower().str.contains('starbucks', na=False)
condition_e = df2['상호명'].str.contains('이디야', na=False) | df2['상호명'].str.lower().str.contains('ediya', na=False)
condition_p = df2['상호명'].str.contains('빽다방', na=False) | df2['상호명'].str.lower().str.contains('paik', na=False)
condition_t = df2['상호명'].str.contains('투썸', na=False) | df2['상호명'].str.lower().str.contains('twosome', na=False)

# %%
starbucks = df2.loc[condition_s]
ediya = df2.loc[condition_e]
paikdabang = df2.loc[condition_p]
twosome = df2.loc[condition_t]

# %%
starbucks['color'] = 'cadetblue'; starbucks['icon'] = 'usd'
ediya['color'] = 'red'; ediya['icon'] = 'tag'
paikdabang['color'] = 'purple'; paikdabang['icon'] = 'map-marker'
twosome['color'] = 'orange'; twosome['icon'] = 'certificate'

# %%
tmp1 = pd.concat([starbucks, ediya])
tmp2 = pd.concat([paikdabang, twosome])
df3 = pd.concat([tmp1, tmp2], ignore_index=True)
df3
# Out:
#       상가업소번호           상호명     지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0   25580127          스타벅스   까치산역점         Q       음식       Q12   커피점/카페
# 1   23369079          스타벅스     등촌점         Q       음식       Q12   커피점/카페
# 2   20088846          스타벅스  가양이마트점         Q       음식       Q12   커피점/카페
# 3   23264112          스타벅스    발산역점         Q       음식       Q12   커피점/카페
# 4   11733281      스타벅스화곡동점    화곡동점         Q       음식       Q12   커피점/카페
# ..       ...           ...     ...       ...      ...       ...      ...
# 75  12110411          투썸강서    송정역점         Q       음식       Q12   커피점/카페
# 76  15891274        투썸플레이스     등촌점         Q       음식       Q12   커피점/카페
# 77  16114499        투썸플레이스   강서구청점         Q       음식       Q12   커피점/카페
# 78  16258737  Twosomeplace     NaN         Q       음식       Q12   커피점/카페
# 79  16047494        투썸플레이스     마곡점         Q       음식       Q12   커피점/카페
#
#    상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                 도로명주소     구우편번호  \
# ...

# %%
# 새로운 csv 파일로 저장
df3.to_csv('../input/coffee2.csv', sep=',', encoding='utf8', index=False)

# %% [markdown]
# ### folium을 사용하여 지도 그리기

# %% [markdown]
# #### 스타벅스, 이디야, 빽다방, 투썸플레이스 전체 매장

# %%
# 매장들의 위도와 경도의 평균을 중심으로 한 배경 지도
mapping = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], zoom_start=13)

for i in df3.index:
    folium.Marker(
        location=[df3['위도'][i], df3['경도'][i]],
        popup=df3['도로명주소'][i], 
        tooltip=f"{df3['상호명'][i]}, {df3['지점명'][i]}",
        icon=folium.Icon(color=df3.color[i], icon=df3.icon[i])
    ).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %% [markdown]
# #### 스타벅스 매장

# %%
starbucks.reset_index(drop=True, inplace=True)

# 스타벅스 매장들의 위도와 경도의 평균을 중심으로 한 배경 지도
mapping = folium.Map(location=[starbucks['위도'].mean(), starbucks['경도'].mean()], zoom_start=13)

for i in starbucks.index:
    folium.Marker(
        location=[starbucks['위도'][i], starbucks['경도'][i]],
        popup=starbucks['도로명주소'][i], 
        tooltip=f"{starbucks['상호명'][i]}, {starbucks['지점명'][i]}",
        icon=folium.Icon(color='cadetblue', icon='usd')
    ).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
starbucks.to_csv('../input/starbucks.csv', sep=',', encoding='utf8', index=False)

# %% [markdown]
# #### 이디야 매장

# %%
ediya.reset_index(drop=True, inplace=True)

# 이디야 매장들의 위도와 경도의 평균을 중심으로 한 배경 지도
mapping = folium.Map(location=[ediya['위도'].mean(), ediya['경도'].mean()], zoom_start=13)

for i in ediya.index:
    folium.Marker(
        location=[ediya['위도'][i], ediya['경도'][i]],
        popup=ediya['도로명주소'][i], 
        tooltip=f"{ediya['상호명'][i]}, {ediya['지점명'][i]}",
        icon=folium.Icon(color='red', icon='tag')
    ).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
ediya.to_csv('../input/ediya.csv', sep=',', encoding='utf8', index=False)

# %% [markdown]
# #### 빽다방 매장

# %%
paikdabang.reset_index(drop=True, inplace=True)

# 빽다방 매장들의 위도와 경도의 평균을 중심으로 한 배경 지도
mapping = folium.Map(location=[paikdabang['위도'].mean(), paikdabang['경도'].mean()], zoom_start=13)

for i in paikdabang.index:
    folium.Marker(
        location=[paikdabang['위도'][i], paikdabang['경도'][i]],
        popup=paikdabang['도로명주소'][i], 
        tooltip=f"{paikdabang['상호명'][i]}, {paikdabang['지점명'][i]}",
        icon=folium.Icon(color='purple', icon='map-marker')
    ).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
paikdabang.to_csv('../input/paikdabang.csv', sep=',', encoding='utf8', index=False)

# %% [markdown]
# #### 투썸플레이스 매장

# %%
twosome.reset_index(drop=True, inplace=True)

# 투썸플레이스 매장들의 위도와 경도의 평균을 중심으로 한 배경 지도
mapping = folium.Map(location=[twosome['위도'].mean(), twosome['경도'].mean()], zoom_start=13)

for i in paikdabang.index:
    folium.Marker(
        location=[twosome['위도'][i], twosome['경도'][i]],
        popup=twosome['도로명주소'][i], 
        tooltip=f"{twosome['상호명'][i]}, {twosome['지점명'][i]}",
        icon=folium.Icon(color='orange', icon='certificate')
    ).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
twosome.to_csv('../input/twosome.csv', sep=',', encoding='utf8', index=False)
