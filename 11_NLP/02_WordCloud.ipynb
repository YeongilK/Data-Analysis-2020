# %% [markdown]
# # 워드 클라우드

# %% [markdown]
# ### 설치
# - conda install -c conda-forge wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# ### Alice in WonderLand

# %%
text = open('./data/Alice.txt').read()
stopwords = set(STOPWORDS)
stopwords.add('said')

# %%
print(stopwords)
# Out:
# {"how's", 'is', 'or', 'themselves', 'if', 'the', 'also', 'there', 'an', 'nor', "that's", 'his', 'not', "isn't", 'were', 'whom', 'who', "you'll", "don't", "he's", 'too', 'a', 'as', 'hence', 'only', "weren't", "aren't", 'before', 'other', 'would', 'for', 'been', 'than', 'all', "shan't", 'in', 'its', 'should', "you'd", 'their', 'these', 'he', 'further', 'r', 'since', 'k', "haven't", 'me', 'else', "they'd", 'www', 'her', "he'll", "where's", 'most', "i'm", "there's", "we'd", 'very', 'are', 'had', 'at', 'herself', 'him', "who's", 'here', 'while', 'http', 'otherwise', "what's", "didn't", "wasn't", 'hers', 'you', 'some', 'against', "she'd", 'we', 'being', "we've", 'be', 'how', "i've", 'off', 'until', 'does', "i'll", 'just', 'where', 'again', 'on', "you're", 'however', 'any', 'them', 'by', 'having', "let's", "why's", 'i', 'theirs', 'to', 'have', 'my', 'through', 'down', 'cannot', 'up', 'com', 'therefore', 'itself', 'can', 'once', 'because', "you've", 'am', 'which', "here's", "it's", "hasn't", 'this', "he'd", "they're", 'with', 'yourself', 'has', 'under', 'ought', 'shall', 'between', "when's", 'ourselves', 'below', 'that', 'yours', "can't", "i'd", 'your', 'when', 'ever', 'she', "won't", 'and', 'more', 'of', 'after', 'then', 'do', 'like', 'myself', "doesn't", 'such', "they'll", 'out', 'over', 'about', "hadn't", 'no', 'but', 'it', 'said', 'each', 'doing', 'above', "mustn't", "she'll", 'they', 'our', 'both', 'why', "we'll", 'so', 'did', 'during', 'own', 'same', 'from', 'into', 'those', "couldn't", "they've", 'ours', "wouldn't", "we're", 'yourselves', "she's", 'get', 'few', 'himself', 'was', 'what', 'could', "shouldn't"}

# %%
wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
wc = wc.generate(text)

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}: {values[i]}')
# Out:
# Alice: 1.0
# little: 0.29508196721311475
# one: 0.27595628415300544
# know: 0.2459016393442623
# went: 0.226775956284153
# thing: 0.2185792349726776
# time: 0.2103825136612022
# Queen: 0.20765027322404372
# see: 0.1830601092896175
# King: 0.17486338797814208

# %%
plt.figure(figsize=(12, 6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### 그림에 표시하기

# %%
mask = np.array(Image.open('./data/Alice_mask.png'))

plt.figure(figsize=(8, 8))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=mask, stopwords=stopwords)
wc = wc.generate(text)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Star Wars - A New Hope

# %%
text = open('./data/A_new_hope.txt').read()
text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('./data/Stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add('int')
stopwords.add('ext')

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, margin=10, random_state=1).generate(text)
default_color = wc.to_array()

# %%
import random
def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60, 100)

# %%
plt.figure(figsize=(12, 12))
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3), interpolation='bilinear')
plt.axis('off')
plt.show()
